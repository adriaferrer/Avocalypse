# %%
import pandas as pd

# %%
production_table = pd.read_csv('/Users/adriaferrer/Avocalypse_data/FAOSTAT_production.csv')

# %%
production_table = production_table[['Area Code','Year Code','Value']]

# %%
production_table.rename(columns={'Value':'Total_protuction_t'}, inplace = True)

# %%
production_table.head()
# Out:
#    Area Code  Year Code  Total_protuction_t
# 0          9       2007              3600.0
# 1          9       2008              3500.0
# 2          9       2009              3600.0
# 3          9       2010              3726.0
# 4          9       2011              3840.0

# %%
harvest_table = pd.read_csv('/Users/adriaferrer/Avocalypse_data/FAOSTAT_area_harvested.csv')

# %%
harvest_table = harvest_table[['Area Code','Year Code','Value']]

# %%
harvest_table.rename(columns={'Value':'Area harvested'},inplace = True)

# %%
harvest_table.head()
# Out:
#    Area Code  Year Code  Area harvested
# 0          9       2007           570.0
# 1          9       2008           540.0
# 2          9       2009           548.0
# 3          9       2010           560.0
# 4          9       2011           570.0

# %%
total_production_data = production_table.merge(harvest_table,on=['Area Code','Year Code'])

# %%
total_production_data.sample(10)
# Out:
#      Area Code  Year Code  Total_protuction_t  Area harvested
# 80          32       2010             56000.0         14200.0
# 221         55       2008               422.0           140.0
# 308         70       2007               132.0            10.0
# 360         87       2015               214.0            20.0
# 710        222       2013               306.0            29.0
# 523        299       2013               570.0            24.0
# 200         50       2009               910.0            88.0
# 276        238       2008             32452.0          5067.0
# 101         40       2009            232202.0         33500.0
# 364         89       2008             94914.0          9435.0

# %%
from sqlalchemy import create_engine
driver = 'mysql+pymysql:'
user = 'root'
password = '17028854'
ip = '35.195.111.11'
database = 'Avocalypse'

connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
engine = create_engine(connection_string)

# %%
total_production_data.to_sql('production',con=engine)

# %%
price_table = pd.read_csv('/Users/adriaferrer/Avocalypse_data/FAOSTAT_pricing.csv')

# %%
price_table.head()
# Out:
#   Domain Code                           Domain  Area Code       Area  \
# 0          PI  Producer Price Indices - Annual          9  Argentina
# 1          PI  Producer Price Indices - Annual          9  Argentina
# 2          PI  Producer Price Indices - Annual          9  Argentina
# 3          PI  Producer Price Indices - Annual          9  Argentina
# 4          PI  Producer Price Indices - Annual          9  Argentina
#
#    Element Code                                 Element  Item Code      Item  \
# 0          5539  Producer Price Index (2004-2006 = 100)        572  Avocados
# 1          5539  Producer Price Index (2004-2006 = 100)        572  Avocados
# 2          5539  Producer Price Index (2004-2006 = 100)        572  Avocados
# 3          5539  Producer Price Index (2004-2006 = 100)        572  Avocados
# 4          5539  Producer Price Index (2004-2006 = 100)        572  Avocados
#
#    Year Code  Year  Unit       Value Flag Flag Description
# 0       2007  2007   NaN  123.086061   Fc  Calculated data
# 1       2008  2008   NaN  155.952012   Fc  Calculated data
# 2       2009  2009   NaN  139.891744   Fc  Calculated data
# 3       2010  2010   NaN  171.921928   Fc  Calculated data
# 4       2011  2011   NaN  215.123273   Fc  Calculated data

# %%
production = pd.read_sql('production', con = engine)

# %%
production.head()
# Out:
#    index  Area Code  Year Code  Total_protuction_t  Area harvested
# 0      0          9       2007              3600.0           570.0
# 1      1          9       2008              3500.0           540.0
# 2      2          9       2009              3600.0           548.0
# 3      3          9       2010              3726.0           560.0
# 4      4          9       2011              3840.0           570.0

# %%
price_table.merge(production, on= 'Area')
